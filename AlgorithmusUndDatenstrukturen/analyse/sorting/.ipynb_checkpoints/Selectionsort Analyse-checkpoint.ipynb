# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Get current size
fig_size = plt.rcParams["figure.figsize"]
 
# Set figure width to 12 and height to 9
fig_size[0] = 15
fig_size[1] = 12
plt.rcParams["figure.figsize"] = fig_size

# %% [markdown]
# ## Loading Data

# %%
raw_data = pd.read_csv('data/SortAnalyse.csv', header=None)

raw_data.columns = ['list_type', 'sort', 'permutation', 'size', 'comparison', 'time', 'pivot']

raw_data
# Out:
#         list_type               sort              permutation    size  \
# 0    FastElements  FastInsertionSort        RandomPermutation   40000
# 1    FastElements  FastInsertionSort        RandomPermutation   50000
# 2    FastElements  FastInsertionSort        RandomPermutation   60000
# 3    FastElements  FastInsertionSort        RandomPermutation   70000
# 4    FastElements  FastInsertionSort        RandomPermutation   80000
# 5    FastElements  FastInsertionSort        RandomPermutation   90000
# 6    FastElements  FastInsertionSort        RandomPermutation  100000
# 7    FastElements  FastInsertionSort        RandomPermutation  110000
# 8    FastElements  FastInsertionSort        RandomPermutation  120000
# 9    FastElements  FastInsertionSort        RandomPermutation  130000
# 10   FastElements  FastInsertionSort        RandomPermutation  140000
# 11   FastElements  FastInsertionSort        RandomPermutation  150000
# 12   FastElements  FastInsertionSort        RandomPermutation  160000
# 13   FastElements  FastInsertionSort        RandomPermutation  170000
# 14   FastElements  FastInsertionSort        RandomPermutation  180000
# 15   FastElements  FastInsertionSort        RandomPermutation  190000
# 16   FastElements  FastInsertionSort        RandomPermutation  200000
# 17   FastElements  FastInsertionSort       ReversePermutation   40000
# 18   FastElements  FastInsertionSort       ReversePermutation   50000
# 19   FastElements  FastInsertionSort       ReversePermutation   60000
# 20   FastElements  FastInsertionSort       ReversePermutation   70000
# 21   FastElements  FastInsertionSort       ReversePermutation   80000
# 22   FastElements  FastInsertionSort       ReversePermutation   90000
# 23   FastElements  FastInsertionSort       ReversePermutation  100000
# 24   FastElements  FastInsertionSort       ReversePermutation  110000
# 25   FastElements  FastInsertionSort       ReversePermutation  120000
# 26   FastElements  FastInsertionSort       ReversePermutation  130000
# 27   FastElements  FastInsertionSort       ReversePermutation  140000
# 28   FastElements  FastInsertionSort       ReversePermutation  150000
# 29   FastElements  FastInsertionSort       ReversePermutation  160000
# ..            ...                ...                      ...     ...
# 157  FastElements  FastInsertionSort       ReversePermutation   80000
# 158  FastElements  FastInsertionSort       ReversePermutation   90000
# 159  FastElements  FastInsertionSort       ReversePermutation  100000
# 160  FastElements  FastInsertionSort       ReversePermutation  110000
# 161  FastElements  FastInsertionSort       ReversePermutation  120000
# 162  FastElements  FastInsertionSort       ReversePermutation  130000
# 163  FastElements  FastInsertionSort       ReversePermutation  140000
# 164  FastElements  FastInsertionSort       ReversePermutation  150000
# 165  FastElements  FastInsertionSort       ReversePermutation  160000
# 166  FastElements  FastInsertionSort       ReversePermutation  170000
# 167  FastElements  FastInsertionSort       ReversePermutation  180000
# 168  FastElements  FastInsertionSort       ReversePermutation  190000
# 169  FastElements  FastInsertionSort       ReversePermutation  200000
# 170  FastElements  FastInsertionSort  AlmostSortedPermutation   40000
# 171  FastElements  FastInsertionSort  AlmostSortedPermutation   50000
# 172  FastElements  FastInsertionSort  AlmostSortedPermutation   60000
# 173  FastElements  FastInsertionSort  AlmostSortedPermutation   70000
# 174  FastElements  FastInsertionSort  AlmostSortedPermutation   80000
# 175  FastElements  FastInsertionSort  AlmostSortedPermutation   90000
# 176  FastElements  FastInsertionSort  AlmostSortedPermutation  100000
# 177  FastElements  FastInsertionSort  AlmostSortedPermutation  110000
# 178  FastElements  FastInsertionSort  AlmostSortedPermutation  120000
# 179  FastElements  FastInsertionSort  AlmostSortedPermutation  130000
# 180  FastElements  FastInsertionSort  AlmostSortedPermutation  140000
# 181  FastElements  FastInsertionSort  AlmostSortedPermutation  150000
# 182  FastElements  FastInsertionSort  AlmostSortedPermutation  160000
# 183  FastElements  FastInsertionSort  AlmostSortedPermutation  170000
# 184  FastElements  FastInsertionSort  AlmostSortedPermutation  180000
# 185  FastElements  FastInsertionSort  AlmostSortedPermutation  190000
# 186  FastElements  FastInsertionSort  AlmostSortedPermutation  200000
#
#       comparison    time  pivot
# 0      399430713    2412      0
# 1      623265531    3916      0
# 2      899494758    4241      0
# 3     1223633796    7262      0
# 4     1605963908   10343      0
# 5     2025639812   10337      0
# 6     2499986360   14298      0
# 7     3022661798   18670      0
# 8     3601898498   21907      0
# 9     4225264103   25217      0
# 10    4913775904   36846      0
# 11    5619135367   36842      0
# 12    6399209499   45111      0
# 13    7230400309   51710      0
# 14    8104140668   53635      0
# 15    9027630438   71632      0
# 16    9992226953   74169      0
# 17     799980000    4184      0
# 18    1249975000    6152      0
# 19    1799970000   10447      0
# 20    2449965000   14104      0
# 21    3199960000   18771      0
# 22    4049955000   24665      0
# 23    4999950000   29581      0
# 24    6049945000   35254      0
# 25    7199940000   40839      0
# 26    8449935000   51253      0
# 27    9799930000   68469      0
# 28   11249925000   82319      0
# 29   12799920000   85399      0
# ..           ...     ...    ...
# 157   3199960000   21842      0
# 158   4049955000   28804      0
# 159   4999950000   32457      0
# 160   6049945000   41088      0
# 161   7199940000   48818      0
# 162   8449935000   63417      0
# 163   9799930000   82308      0
# 164  11249925000   91821      0
# 165  12799920000  102647      0
# 166  14449915000  113029      0
# 167  16199910000  167431      0
# 168  18049905000  172738      0
# 169  19999900000  151657      0
# 170     76135790     491      0
# 171    118471274     747      0
# 172    170026576    1170      0
# 173    231094447    1512      0
# 174    301950368    1994      0
# 175    379720132    2425      0
# 176    467708845    3122      0
# 177    564141156    3702      0
# 178    674784226    4316      0
# 179    786894391    5493      0
# 180    912848386    7813      0
# 181   1047398006    8224      0
# 182   1192424996   11769      0
# 183   1347719084   10153      0
# 184   1507156933   12950      0
# 185   1669437887   13159      0
# 186   1850257859   14124      0
#
# [187 rows x 7 columns]

# %% [markdown]
# ### Grouping and hierarchical indexing

# %%
data = raw_data.groupby(['list_type', 'sort', 'permutation', 'size']).mean()
data
# Out:
#                                                                  comparison  \
# list_type    sort              permutation             size
# FastElements FastInsertionSort AlmostSortedPermutation 40000   7.613579e+07
#                                                        50000   1.184713e+08
#                                                        60000   1.700266e+08
#                                                        70000   2.310944e+08
#                                                        80000   3.019504e+08
#                                                        90000   3.797201e+08
#                                                        100000  4.677088e+08
#                                                        110000  5.641412e+08
#                                                        120000  6.747842e+08
#                                                        130000  7.868944e+08
#                                                        140000  9.128484e+08
#                                                        150000  1.047398e+09
#                                                        160000  1.192425e+09
#                                                        170000  1.347719e+09
#                                                        180000  1.507157e+09
#                                                        190000  1.669438e+09
#                                                        200000  1.850258e+09
#                                RandomPermutation       40000   3.994307e+08
#                                                        50000   6.232655e+08
#                                                        60000   8.994948e+08
#                                                        70000   1.223634e+09
#                                                        80000   1.605964e+09
#                                                        90000   2.025640e+09
#                                                        100000  2.499986e+09
#                                                        110000  3.022662e+09
#                                                        120000  3.601898e+09
#                                                        130000  4.225264e+09
#                                                        140000  4.913776e+09
#                                                        150000  5.619135e+09
#                                                        160000  6.399209e+09
# ...                                                                     ...
#              SelectionSort     RandomPermutation       80000   3.199960e+09
#                                                        90000   4.049955e+09
#                                                        100000  4.999950e+09
#                                                        110000  6.049945e+09
#                                                        120000  7.199940e+09
#                                                        130000  8.449935e+09
#                                                        140000  9.799930e+09
#                                                        150000  1.124992e+10
#                                                        160000  1.279992e+10
#                                                        170000  1.444992e+10
#                                                        180000  1.619991e+10
#                                                        190000  1.804990e+10
#                                                        200000  1.999990e+10
#                                ReversePermutation      40000   7.999800e+08
#                                                        50000   1.249975e+09
#                                                        60000   1.799970e+09
#                                                        70000   2.449965e+09
#                                                        80000   3.199960e+09
#                                                        90000   4.049955e+09
#                                                        100000  4.999950e+09
#                                                        110000  6.049945e+09
#                                                        120000  7.199940e+09
#                                                        130000  8.449935e+09
#                                                        140000  9.799930e+09
#                                                        150000  1.124992e+10
#                                                        160000  1.279992e+10
#                                                        170000  1.444992e+10
#                                                        180000  1.619991e+10
#                                                        190000  1.804990e+10
#                                                        200000  1.999990e+10
#
#                                                                        time  \
# list_type    sort              permutation             size
# FastElements FastInsertionSort AlmostSortedPermutation 40000     461.000000
#                                                        50000     685.000000
#                                                        60000    1016.000000
#                                                        70000    1406.000000
#                                                        80000    1762.000000
#                                                        90000    2170.500000
#                                                        100000   2763.000000
#                                                        110000   3577.500000
#                                                        120000   3879.000000
#                                                        130000   5291.000000
#                                                        140000   7727.500000
#                                                        150000   7909.000000
#                                                        160000  10390.000000
#                                                        170000   9830.500000
#                                                        180000  11726.000000
#                                                        190000  11979.000000
#                                                        200000  13875.000000
#                                RandomPermutation       40000    2436.500000
#                                                        50000    3990.000000
#                                                        60000    5177.000000
#                                                        70000    7781.000000
#                                                        80000   10774.500000
#                                                        90000   11936.000000
#                                                        100000  16002.000000
#                                                        110000  21953.500000
#                                                        120000  22955.500000
#                                                        130000  28315.500000
#                                                        140000  37438.500000
#                                                        150000  39548.500000
#                                                        160000  47406.000000
# ...                                                                     ...
#              SelectionSort     RandomPermutation       80000    2163.000000
#                                                        90000    2791.000000
#                                                        100000   3406.666667
#                                                        110000   4097.333333
#                                                        120000   4944.333333
#                                                        130000   5786.333333
#                                                        140000   6723.333333
#                                                        150000   7790.666667
#                                                        160000   8830.000000
#                                                        170000   9856.333333
#                                                        180000  11274.333333
#                                                        190000  12423.333333
#                                                        200000  13714.333333
#                                ReversePermutation      40000     596.000000
#                                                        50000     992.000000
#                                                        60000    1387.000000
#                                                        70000    1815.000000
#                                                        80000    2400.000000
#                                                        90000    3072.000000
#                                                        100000   3748.000000
#                                                        110000   4615.000000
#                                                        120000   5415.000000
#                                                        130000   6451.000000
#                                                        140000   7364.000000
#                                                        150000   8558.000000
#                                                        160000   9533.000000
#                                                        170000  11016.000000
#                                                        180000  12059.000000
#                                                        190000  13613.000000
#                                                        200000  14952.000000
#
#                                                                pivot
# list_type    sort              permutation             size
# FastElements FastInsertionSort AlmostSortedPermutation 40000     0.0
#                                                        50000     0.0
#                                                        60000     0.0
#                                                        70000     0.0
#                                                        80000     0.0
#                                                        90000     0.0
#                                                        100000    0.0
#                                                        110000    0.0
#                                                        120000    0.0
#                                                        130000    0.0
#                                                        140000    0.0
#                                                        150000    0.0
#                                                        160000    0.0
#                                                        170000    0.0
#                                                        180000    0.0
#                                                        190000    0.0
#                                                        200000    0.0
#                                RandomPermutation       40000     0.0
#                                                        50000     0.0
#                                                        60000     0.0
#                                                        70000     0.0
#                                                        80000     0.0
#                                                        90000     0.0
#                                                        100000    0.0
#                                                        110000    0.0
#                                                        120000    0.0
#                                                        130000    0.0
#                                                        140000    0.0
#                                                        150000    0.0
#                                                        160000    0.0
# ...                                                              ...
#              SelectionSort     RandomPermutation       80000     0.0
#                                                        90000     0.0
#                                                        100000    0.0
#                                                        110000    0.0
#                                                        120000    0.0
#                                                        130000    0.0
#                                                        140000    0.0
#                                                        150000    0.0
#                                                        160000    0.0
#                                                        170000    0.0
#                                                        180000    0.0
#                                                        190000    0.0
#                                                        200000    0.0
#                                ReversePermutation      40000     0.0
#                                                        50000     0.0
#                                                        60000     0.0
#                                                        70000     0.0
#                                                        80000     0.0
#                                                        90000     0.0
#                                                        100000    0.0
#                                                        110000    0.0
#                                                        120000    0.0
#                                                        130000    0.0
#                                                        140000    0.0
#                                                        150000    0.0
#                                                        160000    0.0
#                                                        170000    0.0
#                                                        180000    0.0
#                                                        190000    0.0
#                                                        200000    0.0
#
# [102 rows x 3 columns]

# %% [markdown]
# ## Analyse FastInsertionSort

# %%
is_random_y = data.loc['FastElements','FastInsertionSort','RandomPermutation']['time']
is_random_x = is_random_y.index.values
plt.plot(is_random_x, is_random_y, label='random')

is_reverse_y = data.loc['FastElements','FastInsertionSort','ReversePermutation']['time']
is_reverse_x = is_reverse_y.index.values
plt.plot(is_reverse_x, is_reverse_y, label='reverse')

is_almost_y = data.loc['FastElements','FastInsertionSort','AlmostSortedPermutation']['time']
is_almost_x = is_almost_y.index.values
plt.plot(is_almost_x, is_almost_y, label='almost sorted')

plt.legend()
plt.title('FastInsertionSort Analyse')
plt.xlabel('Größe der Liste')
plt.ylabel('Laufzeit in Sekunden')

plt.show()

# %% [markdown]
# ## Analyse SelectionSort

# %%
ss_random_y = data.loc['FastElements', 'SelectionSort', 'RandomPermutation']['time']
ss_random_x = ss_random_y.index.values
plt.plot(ss_random_x, ss_random_y, label='random')

ss_reverse_y = data.loc['FastElements', 'SelectionSort', 'ReversePermutation']['time']
ss_reverse_x = ss_reverse_y.index.values
plt.plot(ss_reverse_x, ss_reverse_y, label='reverse')

ss_almost_y = data.loc['FastElements', 'SelectionSort', 'AlmostSortedPermutation']['time']
ss_almost_x = ss_almost_y.index.values
plt.plot(ss_almost_x, ss_almost_y, label='almost sorted')


plt.legend()
plt.title('FastInsertionSort Analyse')
plt.xlabel('Größe der Liste')
plt.ylabel('Laufzeit in Sekunden')

plt.show()

# %% [markdown]
# ## FastInsertionSort vs SelectionSort

# %%
plt.plot(is_random_x, is_random_y, label='InsertionSort random')
plt.plot(is_reverse_x, is_reverse_y, label='InsertionSort reverse')
plt.plot(is_almost_x, is_almost_y, label='InsertionSort almost sorted')
plt.plot(ss_random_x, ss_random_y, label='SelectionSort')

plt.legend()
plt.title('FastInsertionSort vs SelectionSort')
plt.xlabel('Größe der Liste')
plt.ylabel('Laufzeit in Sekunden')

plt.show()
